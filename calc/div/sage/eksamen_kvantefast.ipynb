# %%
f(q, D) = sqrt(4*(1-D**2) + q**2)

# %%
plot(f(q, 1), 0, 0.1)
# Out:
# /usr/lib/python3/dist-packages/sage/plot/graphics.py:2327: MatplotlibDeprecationWarning:
# The OldScalarFormatter class was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   x_formatter = OldScalarFormatter()
# /usr/lib/python3/dist-packages/sage/plot/graphics.py:2352: MatplotlibDeprecationWarning:
# The OldScalarFormatter class was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   y_formatter = OldScalarFormatter()
# Graphics object consisting of 1 graphics primitive

# %%
plot(f(q, 0.5), 0, 5)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
b, e, F = var("b, e, F")
D = function("D")(b)
g(b) = tanh(b * sqrt(e**2 + D(b)**2*F**2)/2)/sqrt(e**2 + D(b)**2*F**2)
pprint(g)
# Out:
# $$ b \ {\mapsto}\ \frac{\tanh\left(\frac{1}{2} \, \sqrt{F^{2} D\left(b\right)^{2} + e^{2}} b\right)}{\sqrt{F^{2} D\left(b\right)^{2} + e^{2}}} $$

# %%
eq = simplify(g.diff(b)==0)
pprint(eq)
# Out:
# $$ b \ {\mapsto}\ -\frac{F^{2} D\left(b\right) \tanh\left(\frac{1}{2} \, \sqrt{F^{2} D\left(b\right)^{2} + e^{2}} b\right) \frac{\partial}{\partial b}D\left(b\right)}{{\left(F^{2} D\left(b\right)^{2} + e^{2}\right)}^{\frac{3}{2}}} - \frac{{\left(\frac{F^{2} b D\left(b\right) \frac{\partial}{\partial b}D\left(b\right)}{\sqrt{F^{2} D\left(b\right)^{2} + e^{2}}} + \sqrt{F^{2} D\left(b\right)^{2} + e^{2}}\right)} {\left(\tanh\left(\frac{1}{2} \, \sqrt{F^{2} D\left(b\right)^{2} + e^{2}} b\right)^{2} - 1\right)}}{2 \, \sqrt{F^{2} D\left(b\right)^{2} + e^{2}}} = 0 $$

# %%
pprint(eq.solve(D.diff(b))[0])
# Out:
# $$ \frac{\partial}{\partial b}D\left(b\right) = -\frac{{\left(F^{2} D\left(b\right)^{2} + e^{2}\right)}^{\frac{3}{2}} \tanh\left(\frac{1}{2} \, \sqrt{F^{2} D\left(b\right)^{2} + e^{2}} b\right)^{2} - {\left(F^{2} D\left(b\right)^{2} + e^{2}\right)}^{\frac{3}{2}}}{\sqrt{F^{2} D\left(b\right)^{2} + e^{2}} F^{2} b D\left(b\right) \tanh\left(\frac{1}{2} \, \sqrt{F^{2} D\left(b\right)^{2} + e^{2}} b\right)^{2} - \sqrt{F^{2} D\left(b\right)^{2} + e^{2}} F^{2} b D\left(b\right) + 2 \, F^{2} D\left(b\right) \tanh\left(\frac{1}{2} \, \sqrt{F^{2} D\left(b\right)^{2} + e^{2}} b\right)} $$

# %%
pprint(simplify(tanh(x).diff(x)))
# Out:
# $$ -\tanh\left(x\right)^{2} + 1 $$

# %%
a = var("a")
i = integral(1 / (exp(a*x) - 1), (x, 1, oo), assume(a>1))
pprint(i)
# Out:
# $$ -\frac{\log\left(e^{a} - 1\right)}{a} + 1 $$
