# %%
import sympy as sp
from sympy import cos
x = sp.Symbol("x")
f = lambda x : sp.sqrt(1 - cos(x))
f(x).series(x, 5, 10)
# Out:
# sqrt(1 - cos(5)) + (x - 5)*sin(5)/(2*sqrt(1 - cos(5))) + (x - 5)**2*(-sqrt(1 - cos(5))*sin(5)**2/(8*(-2*cos(5) + cos(5)**2 + 1)) + cos(5)/(4*sqrt(1 - cos(5)))) + (x - 5)**3*(sqrt(1 - cos(5))*sin(5)**3/(16*(-3*cos(5) - cos(5)**3 + 3*cos(5)**2 + 1)) - sqrt(1 - cos(5))*sin(5)*cos(5)/(8*(-2*cos(5) + cos(5)**2 + 1)) - sin(5)/(12*sqrt(1 - cos(5)))) + (x - 5)**4*(-5*sqrt(1 - cos(5))*sin(5)**4/(128*(-4*cos(5) - 4*cos(5)**3 + cos(5)**4 + 6*cos(5)**2 + 1)) - cos(5)/(48*sqrt(1 - cos(5))) - sqrt(1 - cos(5))*cos(5)**2/(32*(-2*cos(5) + cos(5)**2 + 1)) + 3*sqrt(1 - cos(5))*sin(5)**2*cos(5)/(32*(-3*cos(5) - cos(5)**3 + 3*cos(5)**2 + 1)) + sqrt(1 - cos(5))*sin(5)**2/(24*(-2*cos(5) + cos(5)**2 + 1))) + (x - 5)**5*(7*sqrt(1 - cos(5))*sin(5)**5/(256*(-5*cos(5) - 10*cos(5)**3 - cos(5)**5 + 5*cos(5)**4 + 10*cos(5)**2 + 1)) + sqrt(1 - cos(5))*sin(5)*cos(5)/(32*(-2*cos(5) + cos(5)**2 + 1)) + 3*sqrt(1 - cos(5))*sin(5)*cos(5)**2/(64*(-3*cos(5) - cos(5)**3 + 3*cos(5)**2 + 1)) + sin(5)/(240*sqrt(1 - cos(5))) - 
# ...
