# %%
import numpy as np
from numpy import pi, sqrt
import matplotlib.pyplot as plt

from matplotlib import cm
from matplotlib import colors
from matplotlib.animation import FuncAnimation as FA

from scipy.optimize import fsolve

plt.rc("font", family="serif", size=16)
plt.rc("mathtext", fontset="cm")
plt.rc("lines", lw=2)
plt.rc("axes", grid=True)


V = 1
k = sqrt(4/3)
E = lambda n: n*((1 - V*n)**2 + k**2/4)

# %%
n = np.linspace(0, 1.5, 100)
plt.plot(E(n), n)

# %%
E(2/3)
# Out:
# 0.2962962962962963

# %%
n = np.linspace(0, 1.5, 100)
fig, ax = plt.subplots(figsize=(20, 15))

for k in np.linspace(0, 2, 10):
        
    E = [fsolve(lambda E: f(nn, E), 0)[0] for nn in n]
    ax.plot(E, n, "r")

# %%
[fsolve(lambda E: f(nn, E), 0) for nn in n]
# Out:
# [array([0.]),
#  array([0.10688716]),
#  array([0.17914581]),
#  array([0.22295962]),
#  array([0.24451226]),
#  array([0.24998738]),
#  array([0.24556863]),
#  array([0.2374397]),
#  array([0.23178422]),
#  array([0.23478588]),
#  array([0.25262831]),
#  array([0.2914952]),
#  array([0.35757019]),
#  array([0.45703695]),
#  array([0.59607915]),
#  array([0.78088043]),
#  array([1.01762446]),
#  array([1.31249491]),
#  array([1.67167543]),
#  array([2.10134969]),
#  array([2.60770134]),
#  array([3.19691404]),
#  array([3.87517147]),
#  array([4.64865727]),
#  array([5.52355511]),
#  array([6.50604865]),
#  array([7.60232155]),
#  array([8.81855748]),
#  array([10.16094008]),
#  array([11.63565303]),
#  array([13.24887998]),
#  array([15.0068046]),
#  array([16.91561055]),
#  array([18.98148148]),
#  array([21.21060106]),
#  array([23.60915295]),
#  array([26.18332081]),
#  array([28.9392883]),
#  array([31.88323908]),
#  array([35.02135682]),
#  array([38.35982517]),
#  array([41.90482779]),
#  array([45.66254835]),
#  array([49.6391705]),
#  array([53.84087791]),
#  array([58.27385424]),
#  array([62.94428315]),
#  array([67.8583483]),
#  array([73.02223335]),
#  array([78.44212196]),
#  array([84.1241978]),
#  array([90.07464452]),
#  array([96.29964578]),
#  array([102.80538525]),
#  array([109.59804658]),
#  array([116.68381344]),
#  array([124.06886949]),
#  array([131.75939839]),
#  array([139.7615838]),
#  array([148.08160938]),
#  array([156.72565879]),
#  array([165.6999157]),
#  array([175.01056375]),
#  array([184.66378663]),
#  array([194.66576797]),
#  array([205.02269146]),
#  array([215.74074074]),
#  array([226.82609948]),
#  array([238.28495134]),
#  array([250.12347998]),
#  array([262.34786906]),
#  array([274.96430224]),
#  array([287.97896319]),
#  array([301.39803555]),
#  array([315.22770301]),
#  array([329.47414921]),
#  array([344.14355781]),
#  array([359.24211248]),
#  array([374.77599688]),
#  array([390.75139467]),
#  array([407.17448951]),
#  array([424.05146506]),
#  array([441.38850499]),
#  array([459.19179294]),
#  array([477.46751259]),
#  array([496.2218476]),
#  array([515.46098161]),
#  array([535.19109831]),
#  array([555.41838134]),
#  array([576.14901438]),
#  array([597.38918107]),
#  array([619.14506508]),
#  array([641.42285007]),
#  array([664.2287197]),
#  array([687.56885764]),
#  array([711.44944754]),
#  array([735.87667307]),
#  array([760.85671788]),
#  array([786.39576564]),
#  array([812.5])]
